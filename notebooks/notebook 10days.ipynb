# %%
import numpy as np
import pandas as pd
import sys
import warnings
from functions import *
warnings.filterwarnings("ignore")

# I will work with only numpy in main.py for both simplicity's sake, and because of pandas
# handling memory strangely

# for reproducibility
np.random.seed(123)

# print full arrays/dataframes for debugging
np.set_printoptions(threshold=sys.maxsize)

# names of columns extracted.
# note we are not using filenames right now, will need to look at that
# for unique identifier because of inode reuse
feat_cols = ["inode", "pid", "ppid", "uid", "euid", "gid", "egid"]

# import all .dat files from ./ima/ into numpy array
data = None
datanp = import_ima(data)
# Out:
# ./ima/20200115.dat
# next...
# ./ima/20200116.dat
# next...
# ./ima/20200117.dat
# next...
# ./ima/20200118.dat
# next...
# ./ima/20200119.dat
# next...
# ./ima/20200120.dat
# next...
# ./ima/20200121.dat
# next...
# ./ima/20200122.dat
# next...
# ./ima/20200123.dat
# next...
# ./ima/20200124.dat
# next...

# %%
# reduce dimensions with high correlation filter
# drawmap=1 to see heatmap for justification
datanp, red_cols = high_corr_filter(datanp=datanp, feat_cols=feat_cols,
                                    drawmap=1)
print("datanp.shape", datanp.shape)
# Out:
# datanp.shape (130490, 5)

# %%
# reduce dimensions using UMAP (to 2 dimensions), return numpy
dataumap = func_umap(datanp=datanp, feat_cols=red_cols,
                     drawplot=1)
print("dataumap.shape", dataumap.shape)
print("datanp.shape", datanp.shape)
# Out:
# UMAP done! Time elapsed: 362.03419637680054 seconds
# showing UMAP plot...
# dataumap.shape (130490, 7)
# datanp.shape (130490, 5)

# %%
# reduce dimensions using tSNE (to 2 dimensions), return numpy
datatsne = func_tsne(datanp=datanp, feat_cols=red_cols,
                     drawplot=1)
print("datatsne.shape", datatsne.shape)
print("datanp.shape", datanp.shape)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 130490 samples in 1.367s...
# [t-SNE] Computed neighbors for 130490 samples in 3.835s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 130490
# [t-SNE] Computed conditional probabilities for sample 2000 / 130490
# [t-SNE] Computed conditional probabilities for sample 3000 / 130490
# [t-SNE] Computed conditional probabilities for sample 4000 / 130490
# [t-SNE] Computed conditional probabilities for sample 5000 / 130490
# [t-SNE] Computed conditional probabilities for sample 6000 / 130490
# [t-SNE] Computed conditional probabilities for sample 7000 / 130490
# [t-SNE] Computed conditional probabilities for sample 8000 / 130490
# [t-SNE] Computed conditional probabilities for sample 9000 / 130490
# [t-SNE] Computed conditional probabilities for sample 10000 / 130490
# [t-SNE] Computed conditional probabilities for sample 11000 / 130490
# [t-SNE] Computed conditional probabilities for sample 12000 / 130490
# [t-SNE] Computed conditional probabilities for sample 13000 / 130490
# [t-SNE] Computed conditional probabilities for sample 14000 / 130490
# [t-SNE] Computed conditional probabilities for sample 15000 / 130490
# [t-SNE] Computed conditional probabilities for sample 16000 / 130490
# [t-SNE] Computed conditional probabilities for sample 17000 / 130490
# [t-SNE] Computed conditional probabilities for sample 18000 / 130490
# [t-SNE] Computed conditional probabilities for sample 19000 / 130490
# [t-SNE] Computed conditional probabilities for sample 20000 / 130490
# [t-SNE] Computed conditional probabilities for sample 21000 / 130490
# [t-SNE] Computed conditional probabilities for sample 22000 / 130490
# [t-SNE] Computed conditional probabilities for sample 23000 / 130490
# [t-SNE] Computed conditional probabilities for sample 24000 / 130490
# [t-SNE] Computed conditional probabilities for sample 25000 / 130490
# [t-SNE] Computed conditional probabilities for sample 26000 / 130490
# [t-SNE] Computed conditional probabilities for sample 27000 / 130490
# [t-SNE] Computed conditional probabilities for sample 28000 / 130490
# [t-SNE] Computed conditional probabilities for sample 29000 / 130490
# [t-SNE] Computed conditional probabilities for sample 30000 / 130490
# [t-SNE] Computed conditional probabilities for sample 31000 / 130490
# [t-SNE] Computed conditional probabilities for sample 32000 / 130490
# [t-SNE] Computed conditional probabilities for sample 33000 / 130490
# [t-SNE] Computed conditional probabilities for sample 34000 / 130490
# [t-SNE] Computed conditional probabilities for sample 35000 / 130490
# [t-SNE] Computed conditional probabilities for sample 36000 / 130490
# [t-SNE] Computed conditional probabilities for sample 37000 / 130490
# [t-SNE] Computed conditional probabilities for sample 38000 / 130490
# [t-SNE] Computed conditional probabilities for sample 39000 / 130490
# [t-SNE] Computed conditional probabilities for sample 40000 / 130490
# [t-SNE] Computed conditional probabilities for sample 41000 / 130490
# [t-SNE] Computed conditional probabilities for sample 42000 / 130490
# [t-SNE] Computed conditional probabilities for sample 43000 / 130490
# [t-SNE] Computed conditional probabilities for sample 44000 / 130490
# [t-SNE] Computed conditional probabilities for sample 45000 / 130490
# [t-SNE] Computed conditional probabilities for sample 46000 / 130490
# [t-SNE] Computed conditional probabilities for sample 47000 / 130490
# [t-SNE] Computed conditional probabilities for sample 48000 / 130490
# [t-SNE] Computed conditional probabilities for sample 49000 / 130490
# [t-SNE] Computed conditional probabilities for sample 50000 / 130490
# [t-SNE] Computed conditional probabilities for sample 51000 / 130490
# [t-SNE] Computed conditional probabilities for sample 52000 / 130490
# [t-SNE] Computed conditional probabilities for sample 53000 / 130490
# [t-SNE] Computed conditional probabilities for sample 54000 / 130490
# [t-SNE] Computed conditional probabilities for sample 55000 / 130490
# [t-SNE] Computed conditional probabilities for sample 56000 / 130490
# [t-SNE] Computed conditional probabilities for sample 57000 / 130490
# [t-SNE] Computed conditional probabilities for sample 58000 / 130490
# [t-SNE] Computed conditional probabilities for sample 59000 / 130490
# [t-SNE] Computed conditional probabilities for sample 60000 / 130490
# [t-SNE] Computed conditional probabilities for sample 61000 / 130490
# [t-SNE] Computed conditional probabilities for sample 62000 / 130490
# [t-SNE] Computed conditional probabilities for sample 63000 / 130490
# [t-SNE] Computed conditional probabilities for sample 64000 / 130490
# [t-SNE] Computed conditional probabilities for sample 65000 / 130490
# [t-SNE] Computed conditional probabilities for sample 66000 / 130490
# [t-SNE] Computed conditional probabilities for sample 67000 / 130490
# [t-SNE] Computed conditional probabilities for sample 68000 / 130490
# [t-SNE] Computed conditional probabilities for sample 69000 / 130490
# [t-SNE] Computed conditional probabilities for sample 70000 / 130490
# [t-SNE] Computed conditional probabilities for sample 71000 / 130490
# [t-SNE] Computed conditional probabilities for sample 72000 / 130490
# [t-SNE] Computed conditional probabilities for sample 73000 / 130490
# [t-SNE] Computed conditional probabilities for sample 74000 / 130490
# [t-SNE] Computed conditional probabilities for sample 75000 / 130490
# [t-SNE] Computed conditional probabilities for sample 76000 / 130490
# [t-SNE] Computed conditional probabilities for sample 77000 / 130490
# [t-SNE] Computed conditional probabilities for sample 78000 / 130490
# [t-SNE] Computed conditional probabilities for sample 79000 / 130490
# [t-SNE] Computed conditional probabilities for sample 80000 / 130490
# [t-SNE] Computed conditional probabilities for sample 81000 / 130490
# [t-SNE] Computed conditional probabilities for sample 82000 / 130490
# [t-SNE] Computed conditional probabilities for sample 83000 / 130490
# [t-SNE] Computed conditional probabilities for sample 84000 / 130490
# [t-SNE] Computed conditional probabilities for sample 85000 / 130490
# [t-SNE] Computed conditional probabilities for sample 86000 / 130490
# [t-SNE] Computed conditional probabilities for sample 87000 / 130490
# [t-SNE] Computed conditional probabilities for sample 88000 / 130490
# [t-SNE] Computed conditional probabilities for sample 89000 / 130490
# [t-SNE] Computed conditional probabilities for sample 90000 / 130490
# [t-SNE] Computed conditional probabilities for sample 91000 / 130490
# [t-SNE] Computed conditional probabilities for sample 92000 / 130490
# [t-SNE] Computed conditional probabilities for sample 93000 / 130490
# [t-SNE] Computed conditional probabilities for sample 94000 / 130490
# [t-SNE] Computed conditional probabilities for sample 95000 / 130490
# [t-SNE] Computed conditional probabilities for sample 96000 / 130490
# [t-SNE] Computed conditional probabilities for sample 97000 / 130490
# [t-SNE] Computed conditional probabilities for sample 98000 / 130490
# [t-SNE] Computed conditional probabilities for sample 99000 / 130490
# [t-SNE] Computed conditional probabilities for sample 100000 / 130490
# [t-SNE] Computed conditional probabilities for sample 101000 / 130490
# [t-SNE] Computed conditional probabilities for sample 102000 / 130490
# [t-SNE] Computed conditional probabilities for sample 103000 / 130490
# [t-SNE] Computed conditional probabilities for sample 104000 / 130490
# [t-SNE] Computed conditional probabilities for sample 105000 / 130490
# [t-SNE] Computed conditional probabilities for sample 106000 / 130490
# [t-SNE] Computed conditional probabilities for sample 107000 / 130490
# [t-SNE] Computed conditional probabilities for sample 108000 / 130490
# [t-SNE] Computed conditional probabilities for sample 109000 / 130490
# [t-SNE] Computed conditional probabilities for sample 110000 / 130490
# [t-SNE] Computed conditional probabilities for sample 111000 / 130490
# [t-SNE] Computed conditional probabilities for sample 112000 / 130490
# [t-SNE] Computed conditional probabilities for sample 113000 / 130490
# [t-SNE] Computed conditional probabilities for sample 114000 / 130490
# [t-SNE] Computed conditional probabilities for sample 115000 / 130490
# [t-SNE] Computed conditional probabilities for sample 116000 / 130490
# [t-SNE] Computed conditional probabilities for sample 117000 / 130490
# [t-SNE] Computed conditional probabilities for sample 118000 / 130490
# [t-SNE] Computed conditional probabilities for sample 119000 / 130490
# [t-SNE] Computed conditional probabilities for sample 120000 / 130490
# [t-SNE] Computed conditional probabilities for sample 121000 / 130490
# [t-SNE] Computed conditional probabilities for sample 122000 / 130490
# [t-SNE] Computed conditional probabilities for sample 123000 / 130490
# [t-SNE] Computed conditional probabilities for sample 124000 / 130490
# [t-SNE] Computed conditional probabilities for sample 125000 / 130490
# [t-SNE] Computed conditional probabilities for sample 126000 / 130490
# [t-SNE] Computed conditional probabilities for sample 127000 / 130490
# [t-SNE] Computed conditional probabilities for sample 128000 / 130490
# [t-SNE] Computed conditional probabilities for sample 129000 / 130490
# [t-SNE] Computed conditional probabilities for sample 130000 / 130490
# [t-SNE] Computed conditional probabilities for sample 130490 / 130490
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 91.790009
# [t-SNE] KL divergence after 300 iterations: 5.039923
# t-SNE done! Time elapsed: 149.41252636909485 seconds
# showing tSNE plot...
# datatsne.shape (130490, 7)
# datanp.shape (130490, 5)

# %%
# reduce dimensions using PCA, return numpy
data_pca = func_pca(datanp=datanp, feat_cols=red_cols,
                    drawplot=1)
print("data_pca.shape", data_pca.shape)
# Out:
# Explained variation per principal component:[9.99998427e-01 1.09436546e-06 3.79643194e-07]
# showing plot...
# data_pca.shape (130490, 8)
