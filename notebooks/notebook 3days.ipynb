# %%
import numpy as np
import pandas as pd
import sys
import warnings
from functions import *
warnings.filterwarnings("ignore")

# I will work with only numpy in main.py for both simplicity's sake, and because of pandas
# handling memory strangely

# for reproducibility
np.random.seed(123)

# print full arrays/dataframes for debugging
np.set_printoptions(threshold=sys.maxsize)

# names of columns extracted.
# note we are not using filenames right now, will need to look at that
# for unique identifier because of inode reuse
feat_cols = ["inode", "pid", "ppid", "uid", "euid", "gid", "egid"]

# import all .dat files from ./ima/ into numpy array
data = None
datanp = import_ima(data)
# Out:
# ./ima/20200115.dat
# next...
# ./ima/20200116.dat
# next...
# ./ima/20200117.dat
# next...

# %%
# reduce dimensions with high correlation filter
# drawmap=1 to see heatmap for justification
datanp, red_cols = high_corr_filter(datanp=datanp, feat_cols=feat_cols,
                                    drawmap=1)
print("datanp.shape", datanp.shape)
# Out:
# datanp.shape (39080, 5)

# %%
# reduce dimensions using UMAP (to 2 dimensions), return numpy
dataumap = func_umap(datanp=datanp, feat_cols=red_cols,
                     drawplot=1)
print("dataumap.shape", dataumap.shape)
print("datanp.shape", datanp.shape)
# Out:
# UMAP done! Time elapsed: 66.33959197998047 seconds
# showing UMAP plot...
# dataumap.shape (39080, 7)
# datanp.shape (39080, 5)

# %%
# reduce dimensions using tSNE (to 2 dimensions), return numpy
datatsne = func_tsne(datanp=datanp, feat_cols=red_cols,
                     drawplot=1)
print("datatsne.shape", datatsne.shape)
print("datanp.shape", datanp.shape)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 39080 samples in 0.146s...
# [t-SNE] Computed neighbors for 39080 samples in 0.992s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 39080
# [t-SNE] Computed conditional probabilities for sample 2000 / 39080
# [t-SNE] Computed conditional probabilities for sample 3000 / 39080
# [t-SNE] Computed conditional probabilities for sample 4000 / 39080
# [t-SNE] Computed conditional probabilities for sample 5000 / 39080
# [t-SNE] Computed conditional probabilities for sample 6000 / 39080
# [t-SNE] Computed conditional probabilities for sample 7000 / 39080
# [t-SNE] Computed conditional probabilities for sample 8000 / 39080
# [t-SNE] Computed conditional probabilities for sample 9000 / 39080
# [t-SNE] Computed conditional probabilities for sample 10000 / 39080
# [t-SNE] Computed conditional probabilities for sample 11000 / 39080
# [t-SNE] Computed conditional probabilities for sample 12000 / 39080
# [t-SNE] Computed conditional probabilities for sample 13000 / 39080
# [t-SNE] Computed conditional probabilities for sample 14000 / 39080
# [t-SNE] Computed conditional probabilities for sample 15000 / 39080
# [t-SNE] Computed conditional probabilities for sample 16000 / 39080
# [t-SNE] Computed conditional probabilities for sample 17000 / 39080
# [t-SNE] Computed conditional probabilities for sample 18000 / 39080
# [t-SNE] Computed conditional probabilities for sample 19000 / 39080
# [t-SNE] Computed conditional probabilities for sample 20000 / 39080
# [t-SNE] Computed conditional probabilities for sample 21000 / 39080
# [t-SNE] Computed conditional probabilities for sample 22000 / 39080
# [t-SNE] Computed conditional probabilities for sample 23000 / 39080
# [t-SNE] Computed conditional probabilities for sample 24000 / 39080
# [t-SNE] Computed conditional probabilities for sample 25000 / 39080
# [t-SNE] Computed conditional probabilities for sample 26000 / 39080
# [t-SNE] Computed conditional probabilities for sample 27000 / 39080
# [t-SNE] Computed conditional probabilities for sample 28000 / 39080
# [t-SNE] Computed conditional probabilities for sample 29000 / 39080
# [t-SNE] Computed conditional probabilities for sample 30000 / 39080
# [t-SNE] Computed conditional probabilities for sample 31000 / 39080
# [t-SNE] Computed conditional probabilities for sample 32000 / 39080
# [t-SNE] Computed conditional probabilities for sample 33000 / 39080
# [t-SNE] Computed conditional probabilities for sample 34000 / 39080
# [t-SNE] Computed conditional probabilities for sample 35000 / 39080
# [t-SNE] Computed conditional probabilities for sample 36000 / 39080
# [t-SNE] Computed conditional probabilities for sample 37000 / 39080
# [t-SNE] Computed conditional probabilities for sample 38000 / 39080
# [t-SNE] Computed conditional probabilities for sample 39000 / 39080
# [t-SNE] Computed conditional probabilities for sample 39080 / 39080
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 73.378998
# [t-SNE] KL divergence after 300 iterations: 3.374330
# t-SNE done! Time elapsed: 48.09152555465698 seconds
# showing tSNE plot...
# datatsne.shape (39080, 7)
# datanp.shape (39080, 5)

# %%
# reduce dimensions using PCA, return numpy
data_pca = func_pca(datanp=datanp, feat_cols=red_cols,
                    drawplot=1)
print("data_pca.shape", data_pca.shape)
# Out:
# Explained variation per principal component:[9.99155531e-01 6.28239200e-04 1.67499739e-04]
# showing plot...
# data_pca.shape (39080, 8)
