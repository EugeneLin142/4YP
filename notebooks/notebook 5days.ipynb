# %%
import numpy as np
import pandas as pd
import sys
import warnings
from functions import *
warnings.filterwarnings("ignore")

# I will work with only numpy in main.py for both simplicity's sake, and because of pandas
# handling memory strangely

# for reproducibility
np.random.seed(123)

# print full arrays/dataframes for debugging
np.set_printoptions(threshold=sys.maxsize)

# names of columns extracted.
# note we are not using filenames right now, will need to look at that
# for unique identifier because of inode reuse
feat_cols = ["inode", "pid", "ppid", "uid", "euid", "gid", "egid"]

# import all .dat files from ./ima/ into numpy array
data = None
datanp = import_ima(data)
# Out:
# ./ima/20200115.dat
# next...
# ./ima/20200116.dat
# next...
# ./ima/20200117.dat
# next...
# ./ima/20200118.dat
# next...
# ./ima/20200119.dat
# next...

# %%
# reduce dimensions with high correlation filter
# drawmap=1 to see heatmap for justification
datanp, red_cols = high_corr_filter(datanp=datanp, feat_cols=feat_cols,
                                    drawmap=1)
print("datanp.shape", datanp.shape)
# Out:
# datanp.shape (60274, 5)

# %%
# reduce dimensions using UMAP (to 2 dimensions), return numpy
dataumap = func_umap(datanp=datanp, feat_cols=red_cols,
                     drawplot=1)
print("dataumap.shape", dataumap.shape)
# Out:
# UMAP done! Time elapsed: 206.71376419067383 seconds
# showing UMAP plot...
# dataumap.shape (60274, 7)
# datanp.shape (60274, 5)

# %%
# reduce dimensions using tSNE (to 2 dimensions), return numpy
datatsne = func_tsne(datanp=datanp, feat_cols=red_cols,
                     drawplot=1)
print("datatsne.shape", datatsne.shape)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 60274 samples in 0.198s...
# [t-SNE] Computed neighbors for 60274 samples in 1.796s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 60274
# [t-SNE] Computed conditional probabilities for sample 2000 / 60274
# [t-SNE] Computed conditional probabilities for sample 3000 / 60274
# [t-SNE] Computed conditional probabilities for sample 4000 / 60274
# [t-SNE] Computed conditional probabilities for sample 5000 / 60274
# [t-SNE] Computed conditional probabilities for sample 6000 / 60274
# [t-SNE] Computed conditional probabilities for sample 7000 / 60274
# [t-SNE] Computed conditional probabilities for sample 8000 / 60274
# [t-SNE] Computed conditional probabilities for sample 9000 / 60274
# [t-SNE] Computed conditional probabilities for sample 10000 / 60274
# [t-SNE] Computed conditional probabilities for sample 11000 / 60274
# [t-SNE] Computed conditional probabilities for sample 12000 / 60274
# [t-SNE] Computed conditional probabilities for sample 13000 / 60274
# [t-SNE] Computed conditional probabilities for sample 14000 / 60274
# [t-SNE] Computed conditional probabilities for sample 15000 / 60274
# [t-SNE] Computed conditional probabilities for sample 16000 / 60274
# [t-SNE] Computed conditional probabilities for sample 17000 / 60274
# [t-SNE] Computed conditional probabilities for sample 18000 / 60274
# [t-SNE] Computed conditional probabilities for sample 19000 / 60274
# [t-SNE] Computed conditional probabilities for sample 20000 / 60274
# [t-SNE] Computed conditional probabilities for sample 21000 / 60274
# [t-SNE] Computed conditional probabilities for sample 22000 / 60274
# [t-SNE] Computed conditional probabilities for sample 23000 / 60274
# [t-SNE] Computed conditional probabilities for sample 24000 / 60274
# [t-SNE] Computed conditional probabilities for sample 25000 / 60274
# [t-SNE] Computed conditional probabilities for sample 26000 / 60274
# [t-SNE] Computed conditional probabilities for sample 27000 / 60274
# [t-SNE] Computed conditional probabilities for sample 28000 / 60274
# [t-SNE] Computed conditional probabilities for sample 29000 / 60274
# [t-SNE] Computed conditional probabilities for sample 30000 / 60274
# [t-SNE] Computed conditional probabilities for sample 31000 / 60274
# [t-SNE] Computed conditional probabilities for sample 32000 / 60274
# [t-SNE] Computed conditional probabilities for sample 33000 / 60274
# [t-SNE] Computed conditional probabilities for sample 34000 / 60274
# [t-SNE] Computed conditional probabilities for sample 35000 / 60274
# [t-SNE] Computed conditional probabilities for sample 36000 / 60274
# [t-SNE] Computed conditional probabilities for sample 37000 / 60274
# [t-SNE] Computed conditional probabilities for sample 38000 / 60274
# [t-SNE] Computed conditional probabilities for sample 39000 / 60274
# [t-SNE] Computed conditional probabilities for sample 40000 / 60274
# [t-SNE] Computed conditional probabilities for sample 41000 / 60274
# [t-SNE] Computed conditional probabilities for sample 42000 / 60274
# [t-SNE] Computed conditional probabilities for sample 43000 / 60274
# [t-SNE] Computed conditional probabilities for sample 44000 / 60274
# [t-SNE] Computed conditional probabilities for sample 45000 / 60274
# [t-SNE] Computed conditional probabilities for sample 46000 / 60274
# [t-SNE] Computed conditional probabilities for sample 47000 / 60274
# [t-SNE] Computed conditional probabilities for sample 48000 / 60274
# [t-SNE] Computed conditional probabilities for sample 49000 / 60274
# [t-SNE] Computed conditional probabilities for sample 50000 / 60274
# [t-SNE] Computed conditional probabilities for sample 51000 / 60274
# [t-SNE] Computed conditional probabilities for sample 52000 / 60274
# [t-SNE] Computed conditional probabilities for sample 53000 / 60274
# [t-SNE] Computed conditional probabilities for sample 54000 / 60274
# [t-SNE] Computed conditional probabilities for sample 55000 / 60274
# [t-SNE] Computed conditional probabilities for sample 56000 / 60274
# [t-SNE] Computed conditional probabilities for sample 57000 / 60274
# [t-SNE] Computed conditional probabilities for sample 58000 / 60274
# [t-SNE] Computed conditional probabilities for sample 59000 / 60274
# [t-SNE] Computed conditional probabilities for sample 60000 / 60274
# [t-SNE] Computed conditional probabilities for sample 60274 / 60274
# [t-SNE] Mean sigma: 0.000000

# %%
# reduce dimensions using PCA, return numpy
data_pca = func_pca(datanp=datanp, feat_cols=red_cols,
                    drawplot=1)
print("data_pca.shape", data_pca.shape)
